# %%
import os
import pandas as pd
from scipy.io import loadmat

# %%
# Define the base directory where the files are stored
base_dir = "../data/modified/"

# %%
# Load data for one subject and one pollutant (CO2)
subject = 1
pollutant = 'CO2'

# Build paths
subj_folder_name = f"S{subject:02d}"    # e.g., S01
subj_prefix = f"S{subject}"             # e.g., S1
base_dir = "../data/modified/"
subject_path = os.path.join(base_dir, subj_folder_name)

# %%
# Container for all CO2-related data
co2_data = {}

# Load .mat file
mat_file = f"{subj_prefix}{pollutant}.mat"
mat_path = os.path.join(subject_path, mat_file)
if os.path.exists(mat_path):
    mat_contents = loadmat(mat_path)
    mat_vars = {k: v for k, v in mat_contents.items() if not k.startswith('__')}
    co2_data['mat'] = mat_vars
    print(f"✅ Loaded {mat_file} with fields: {list(mat_vars.keys())}")
else:
    print(f"⚠️  .mat file {mat_file} not found")
# Out:
# ✅ Loaded S1CO2.mat with fields: ['A', 'A1', 'AB', 'AB1', 'B', 'B1', 'BC', 'BC1', 'C', 'C1', 'CD', 'CD1', 'D', 'D1', 'DE', 'DE1', 'E', 'E1', 'EF', 'EF1', 'F', 'F1', 'FG', 'FG1', 'G', 'G1', 'GH', 'GH1', 'Part', 'S', 'Sin', 'i', 'k', 'l', 'lt', 'nAB', 'nBC', 'nCD', 'nDE', 'nEF', 'nFG', 'nGH', 'nS', 't', 't1', 'tot', 'ttt']

# %%
# Extract example variables from the .mat file
co2_matrix = mat_vars.get('AB1')
if co2_matrix is not None:
    print(f"CO2 matrix shape: {co2_matrix.shape}")
    print(f"CO2 matrix preview:\n{co2_matrix[:5, :]}")
# Out:
# CO2 matrix shape: (1, 36)
# CO2 matrix preview:
# [[1151.14991889 1283.11810671 1256.29312472 1076.73628087  925.5689814
#    851.66907122  757.431317    666.629958    670.49141224  704.81647877
#    667.15472254  629.9131716   669.96468855  712.89099317  696.32528992
#    677.46725722  691.69368719  674.46609672  614.97294412  605.51471639
#    679.81268727  723.25166195  647.46176187  550.84383394  553.06934775
#    617.49977478  645.04508719  639.46930745  644.98965239  647.77495127
#    632.11763015  623.65866202  638.00594462  639.64608184  616.2925825
#    616.61443586]]

# %% [markdown]
# ## Datetime values (t1 and ttt) are saved as strings

# %%
time_array = mat_vars.get('t1')  # might be time values t1 and ttt
if time_array is not None:
    print(f"Time array shape: {time_array.shape}")
    print(f"Time array preview:\n{time_array[:5]}")
# Out:
# Time array shape: (207,)
# Time array preview:
# ['10:22:38' '10:23:04' '10:23:28' '10:24:20' '10:24:36']

# %%
pd.to_datetime(time_array, format='%H:%M:%S')
# Out:
# DatetimeIndex(['1900-01-01 10:22:38', '1900-01-01 10:23:04',
#                '1900-01-01 10:23:28', '1900-01-01 10:24:20',
#                '1900-01-01 10:24:36', '1900-01-01 10:25:02',
#                '1900-01-01 10:25:26', '1900-01-01 10:26:08',
#                '1900-01-01 10:26:28', '1900-01-01 10:26:52',
#                ...
#                '1900-01-01 11:56:41', '1900-01-01 11:56:49',
#                '1900-01-01 11:57:13', '1900-01-01 11:57:39',
#                '1900-01-01 11:58:03', '1900-01-01 11:58:23',
#                '1900-01-01 11:58:49', '1900-01-01 11:59:13',
#                '1900-01-01 11:59:45', '1900-01-01 12:00:03'],
#               dtype='datetime64[ns]', length=207, freq=None)

# %%
pd.to_datetime(time_array, format='%H:%M:%S').time
# Out:
# array([datetime.time(10, 22, 38), datetime.time(10, 23, 4),
#        datetime.time(10, 23, 28), datetime.time(10, 24, 20),
#        datetime.time(10, 24, 36), datetime.time(10, 25, 2),
#        datetime.time(10, 25, 26), datetime.time(10, 26, 8),
#        datetime.time(10, 26, 28), datetime.time(10, 26, 52),
#        datetime.time(10, 27, 16), datetime.time(10, 27, 40),
#        datetime.time(10, 28, 4), datetime.time(10, 28, 30),
#        datetime.time(10, 28, 54), datetime.time(10, 29, 30),
#        datetime.time(10, 29, 46), datetime.time(10, 30, 12),
#        datetime.time(10, 30, 24), datetime.time(10, 31, 6),
#        datetime.time(10, 31, 30), datetime.time(10, 31, 52),
#        datetime.time(10, 32, 14), datetime.time(10, 32, 40),
#        datetime.time(10, 33, 4), datetime.time(10, 33, 28),
#        datetime.time(10, 33, 52), datetime.time(10, 35),
#        datetime.time(10, 35, 8), datetime.time(10, 35, 32),
#        datetime.time(10, 36, 6), datetime.time(10, 36, 38),
#        datetime.time(10, 37, 2), datetime.time(10, 37, 18),
#        datetime.time(10, 37, 42), datetime.time(10, 38, 6),
#        datetime.time(10, 38, 26), datetime.time(10, 39, 16),
#        datetime.time(10, 41, 2), datetime.time(10, 41, 6),
#        datetime.time(10, 41, 32), datetime.time(10, 42, 12),
#        datetime.time(10, 42, 50), datetime.time(10, 43, 2),
#        datetime.time(10, 43, 28), datetime.time(10, 43, 58),
#        datetime.time(10, 44, 18), datetime.time(10, 44, 38),
#        datetime.time(10, 45, 2), datetime.time(10, 45, 30),
#        datetime.time(10, 46, 6), datetime.time(10, 46, 26),
#        datetime.time(10, 46, 50), datetime.time(10, 47, 14),
#        datetime.time(10, 47, 38), datetime.time(10, 48, 2),
#        datetime.time(10, 48, 48), datetime.time(10, 49, 18),
#        datetime.time(10, 49, 40), datetime.time(10, 50, 10),
#        datetime.time(10, 51, 6), datetime.time(10, 52, 2),
#        datetime.time(10, 52, 14), datetime.time(10, 52, 40),
#        datetime.time(10, 53, 4), datetime.time(10, 53, 42),
#        datetime.time(10, 53, 54), datetime.time(10, 54, 18),
#        datetime.time(10, 54, 38), datetime.time(10, 55, 30),
#        datetime.time(10, 56, 6), datetime.time(10, 56, 46),
#        datetime.time(10, 56, 54), datetime.time(10, 57, 20),
#        datetime.time(10, 57, 44), datetime.time(10, 58, 4),
#        datetime.time(10, 58, 36), datetime.time(10, 58, 48),
#        datetime.time(10, 59, 12), datetime.time(10, 59, 36),
#        datetime.time(11, 0), datetime.time(11, 0, 24),
#        datetime.time(11, 1), datetime.time(11, 1, 24),
#        datetime.time(11, 2, 4), datetime.time(11, 2, 16),
#        datetime.time(11, 2, 42), datetime.time(11, 3),
#        datetime.time(11, 3, 24), datetime.time(11, 4, 24),
#        datetime.time(11, 4, 40), datetime.time(11, 5, 4),
#        datetime.time(11, 5, 44), datetime.time(11, 7),
#        datetime.time(11, 7, 16), datetime.time(11, 7, 40),
#        datetime.time(11, 8, 8), datetime.time(11, 9, 16),
#        datetime.time(11, 10, 10), datetime.time(11, 10, 40),
#        datetime.time(11, 11, 28), datetime.time(11, 11, 52),
#        datetime.time(11, 12, 20), datetime.time(11, 12, 56),
#        datetime.time(11, 13), datetime.time(11, 13, 24),
#        datetime.time(11, 14, 38), datetime.time(11, 15, 8),
#        datetime.time(11, 16, 32), datetime.time(11, 17, 18),
#        datetime.time(11, 17, 40), datetime.time(11, 18, 6),
#        datetime.time(11, 19, 4), datetime.time(11, 19, 18),
#        datetime.time(11, 19, 42), datetime.time(11, 20, 10),
#        datetime.time(11, 20, 52), datetime.time(11, 21, 6),
#        datetime.time(11, 21, 28), datetime.time(11, 22),
#        datetime.time(11, 22, 14), datetime.time(11, 22, 40),
#        datetime.time(11, 23, 4), datetime.time(11, 23, 24),
#        datetime.time(11, 23, 52), datetime.time(11, 24, 22),
#        datetime.time(11, 24, 50), datetime.time(11, 25, 2),
#        datetime.time(11, 25, 26), datetime.time(11, 26, 6),
#        datetime.time(11, 26, 30), datetime.time(11, 26, 54),
#        datetime.time(11, 27, 14), datetime.time(11, 27, 40),
#        datetime.time(11, 28, 6), datetime.time(11, 28, 48),
#        datetime.time(11, 29, 12), datetime.time(11, 30),
#        datetime.time(11, 30, 28), datetime.time(11, 31, 4),
#        datetime.time(11, 31, 28), datetime.time(11, 31, 52),
#        datetime.time(11, 32, 14), datetime.time(11, 32, 38),
#        datetime.time(11, 33, 12), datetime.time(11, 33, 28),
#        datetime.time(11, 33, 52), datetime.time(11, 34, 20),
#        datetime.time(11, 34, 38), datetime.time(11, 35, 4),
#        datetime.time(11, 35, 28), datetime.time(11, 36, 4),
#        datetime.time(11, 36, 32), datetime.time(11, 36, 52),
#        datetime.time(11, 37, 18), datetime.time(11, 37, 50),
#        datetime.time(11, 38, 12), datetime.time(11, 38, 28),
#        datetime.time(11, 38, 50), datetime.time(11, 39, 26),
#        datetime.time(11, 39, 38), datetime.time(11, 40, 6),
#        datetime.time(11, 40, 30), datetime.time(11, 41, 4),
#        datetime.time(11, 41, 24), datetime.time(11, 41, 52),
#        datetime.time(11, 42, 36), datetime.time(11, 43, 8),
#        datetime.time(11, 43, 38), datetime.time(11, 43, 50),
#        datetime.time(11, 44, 16), datetime.time(11, 44, 40),
#        datetime.time(11, 45, 4), datetime.time(11, 45, 30),
#        datetime.time(11, 46, 11), datetime.time(11, 46, 49),
#        datetime.time(11, 47, 17), datetime.time(11, 47, 39),
#        datetime.time(11, 48, 5), datetime.time(11, 48, 25),
#        datetime.time(11, 48, 57), datetime.time(11, 49, 25),
#        datetime.time(11, 49, 41), datetime.time(11, 50, 1),
#        datetime.time(11, 50, 25), datetime.time(11, 51, 5),
#        datetime.time(11, 51, 29), datetime.time(11, 51, 47),
#        datetime.time(11, 52, 17), datetime.time(11, 52, 41),
#        datetime.time(11, 53, 5), datetime.time(11, 53, 23),
#        datetime.time(11, 53, 47), datetime.time(11, 54, 13),
#        datetime.time(11, 54, 47), datetime.time(11, 55, 41),
#        datetime.time(11, 56, 5), datetime.time(11, 56, 41),
#        datetime.time(11, 56, 49), datetime.time(11, 57, 13),
#        datetime.time(11, 57, 39), datetime.time(11, 58, 3),
#        datetime.time(11, 58, 23), datetime.time(11, 58, 49),
#        datetime.time(11, 59, 13), datetime.time(11, 59, 45),
#        datetime.time(12, 0, 3)], dtype=object)

# %% [markdown]
# ## Tables ('TableResampled' and 'CO2') saved as .csv files

# %%
file_name = subj_prefix + "_CO2_TableResampled.csv"
file_path = os.path.join(subject_path, file_name)
co2_table = pd.read_csv(file_path)
co2_table.head()
# Out:
#              S       ttt  Var3
# 0  1030.695381  10:22:38     0
# 1  1052.020894  10:22:39     0
# 2  1071.102377  10:22:40     0
# 3  1087.935351  10:22:41     0
# 4  1102.533810  10:22:42     0

# %%
file_name = subj_prefix + "_CO2_CO2.csv"
file_path = os.path.join(subject_path, file_name)
co2_table = pd.read_csv(file_path)
co2_table.head()
# Out:
#        S1         t     S2  VarName4      S3  VarName6     S4  VarName8  \
# 0  1030.0  0.432384  936.0  0.416181  1500.0  0.610775  847.0  0.446887
# 1  1025.0  0.432685  889.0  0.416319  1398.0  0.611192  831.0  0.447164
# 2  1305.0  0.432963  897.0  0.416597  1318.0  0.611470  836.0  0.447442
# 3  1036.0  0.433565  911.0  0.416875  1315.0  0.611748  853.0  0.447813
# 4  1087.0  0.433750  894.0  0.417153  1327.0  0.612025  894.0  0.447951
#
#       S5  VarName10  ...     S16  VarName32     S17  VarName34     S18  \
# 0  936.0   0.630775  ...  1017.0   0.426238  1686.0   0.598241  2192.0
# 1  957.0   0.630961  ...  1021.0   0.426563  1612.0   0.598426  2075.0
# 2  939.0   0.631238  ...  1027.0   0.426840  1570.0   0.598727  1966.0
# 3  862.0   0.631701  ...  1013.0   0.427049  1606.0   0.599282  1895.0
# 4  865.0   0.631840  ...   970.0   0.427326  1618.0   0.599560  1802.0
#
#    VarName36     S19  VarName38     S20  VarName40
# 0   0.616019  1126.0   0.458137  1440.0   0.597187
# 1   0.616227  1063.0   0.458414  1433.0   0.597326
# 2   0.616620  1035.0   0.458715  1400.0   0.597697
# 3   0.616806  1006.0   0.459039  1398.0   0.597975
# 4   0.617384  1005.0   0.459317  1414.0   0.598160
#
# [5 rows x 40 columns]
