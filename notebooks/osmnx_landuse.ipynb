# %%
import osmnx as ox
from osmnx.features import features_from_bbox
import geopandas as gpd
from src.geometric_utils import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/processed_data/S1CO2-approx-coordinates.csv')

# %%
west, south, east, north = 9.2257, 45.47162, 9.23768, 45.48537
bbox = (west, south, east, north)

# %%
# c) land-use areas (residential, commercial, industrial…)
tags_landuse = {"landuse": True}
gdf_landuse = features_from_bbox(bbox, tags_landuse)

# %%
for col in gdf_landuse.columns:
    print(col)
    print(len(gdf_landuse[~gdf_landuse[col].isna()]))
    print(gdf_landuse[~gdf_landuse[col].isna()][col].unique())
    print("==="*20)

# %%
# gdf_landuse['landuse] == ['education' 'grass' 'construction' 'religious' 'industrial' 'churchyard'
#  'commercial' 'residential' 'recreation_ground' 'greenhouse_horticulture'
#  'railway' 'flowerbed']

#gdf_landuse['natural] = grassland
